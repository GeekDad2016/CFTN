# %% [markdown]
# !pip install -r requirements.txt

# %% [markdown]
# !apt-get update && apt-get install -y tmux

# %% [markdown]
# import wandb
#
# wandb.login()

# %% [markdown]
# !python -m tools.train_cftn

# %%
# !python tools/train_cftn_v2.py --config config/vqvae_naruto.yaml --use_wandb
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Loading VQ-VAE from vqvae_naruto_v2/best_vqvae_naruto_v2.pth
# wandb: Currently logged in as: kaipo to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run stfyi9rd (0.3s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /workspace/CFTN/wandb/run-20251223_172935-stfyi9rd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deep-hill-6
# wandb: ⭐️ View project at https://wandb.ai/kaipo/vqvae-naruto-cftn-v2
# wandb: 🚀 View run at https://wandb.ai/kaipo/vqvae-naruto-cftn-v2/runs/stfyi9rd
# 🚀 STAGE 2A: Bidirectional Training...
# Ep 0 | GenL: 3.531 | CapL: 3.064 | Acc: 6.1%: 100%|█| 76/76 [00:46<00:00,  1.64i
#
# 📝 Evaluating Captioning on 3 images...
# ------------------------------------------------------------
# ...

# %%
# !torchrun --nproc_per_node=1 tools/train_cftn_v2.py --config config/vqvae_naruto.yaml --use_wandb
# Out:
# Loading VQ-VAE from vqvae_naruto_v2/best_vqvae_naruto_v2.pth
# wandb: Currently logged in as: kaipo to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run mpeyctr7 (0.2s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /workspace/CFTN/wandb/run-20251223_201352-mpeyctr7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run northern-tree-8
# wandb: ⭐️ View project at https://wandb.ai/kaipo/vqvae-naruto-cftn-v2
# wandb: 🚀 View run at https://wandb.ai/kaipo/vqvae-naruto-cftn-v2/runs/mpeyctr7
# 🚀 STAGE 2A: Bidirectional Training (Adaptive Weighted)...
# Ep 0 | G_L: 3.646 | C_L: 5.786 | W_C: 0.010 | Acc: 6.1%: 100%|█| 76/76 [00:44<00
#
# 📝 Evaluating Captioning on 3 images...
# ------------------------------------------------------------
# ...

# %% [markdown]
# !python tools/verify_vqvae.py --config config/vqvae_naruto.yaml

# %% [markdown]
# ps aux | grep tmux
#
#
# apt-get update && apt-get install -y tmux
#
# tmux new -s training
#
# python -m tools.train_lstm
#
# tmux attach -t training
